# %%
# %run zipf -h
# Out:
# usage: zipf.py [-h] [-f FILE] [-i] [-w WORDS] -n LENGTH [-t TOKENS]
#
# process some inputs.
#
# options:
#   -h, --help            show this help message and exit
#   -f FILE, --file FILE  load text from a file
#   -i, --input           get text input prompt
#   -w WORDS, --words WORDS
#                         words or single letters [Words by default]
#   -n LENGTH, --length LENGTH
#                         percentage or used text
#   -t TOKENS, --tokens TOKENS
#                         plot by given number of tokens

# %%
# %run zipf -i -w 1 -n 100 -t 10
# Out:
# Text: to jest przykladowy tekst

# %%
# %run zipf -f lorem.txt -w 1 -n 40
# Out:
# Text: Lorem ipsum dolor sit amet, consectetur adipiscing elit. Vestibulum non turpis
# in diam porttitor sodales. Duis tristique, orci vel posuere dignissim, elit
# ligula porttitor purus, nec commodo nisl mauris commodo metus. Vivamus vitae
# sollicitudin tellus. Integer vehicula volutpat rutrum. Fusce at enim quis lorem
# tempus accumsan. Suspendisse risus nulla, dictum sit amet venenatis vel,
# pellentesque id lacus. Phasellus fermentum felis mattis sem auctor blandit.
# Pellentesque nulla erat, sagittis sit amet est non, pellentesque convallis
# tellus. Nulla placerat tortor sit amet tincidunt volutpat. Nunc metus quam,
# varius et justo at, hendrerit suscipit nibh. Curabitur lorem nibh, maximus
# mollis fermentum sed, rhoncus et enim.
#
# Aenean condimentum condimentum neque et pretium. Sed orci lacus, aliquam non
# molestie eu, rutrum nec lacus. Quisque varius bibendum enim fringilla mollis.
# Cras condimentum congue tempus. Vestibulum imperdiet finibus nunc, at egestas
# ...
